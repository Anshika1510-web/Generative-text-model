# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in c:\users\anshi\anaconda3\lib\site-packages (4.51.3)
# Collecting torch
#   Downloading torch-2.7.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (0.31.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\anshi\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anshi\anaconda3\lib\site-packages (from torch) (4.11.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\anshi\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\anshi\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\anshi\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\anshi\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anshi\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\anshi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anshi\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anshi\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anshi\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anshi\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anshi\anaconda3\lib\site-packages (from requests->transformers) (2024.12.14)
# Downloading torch-2.7.0-cp312-cp312-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 1.6/212.5 MB 9.3 MB/s eta 0:00:23
#     --------------------------------------- 3.4/212.5 MB 8.8 MB/s eta 0:00:24
#    - -------------------------------------- 5.8/212.5 MB 9.3 MB/s eta 0:00:23
#    - -------------------------------------- 7.6/212.5 MB 9.4 MB/s eta 0:00:22
#    - -------------------------------------- 9.2/212.5 MB 9.5 MB/s eta 0:00:22
#    - -------------------------------------- 10.5/212.5 MB 8.6 MB/s eta 0:00:24
#    -- ------------------------------------- 12.3/212.5 MB 8.5 MB/s eta 0:00:24
#    -- ------------------------------------- 14.4/212.5 MB 8.6 MB/s eta 0:00:23
#    -- ------------------------------------- 15.7/212.5 MB 8.4 MB/s eta 0:00:24
#    --- ------------------------------------ 17.6/212.5 MB 8.5 MB/s eta 0:00:24
#    --- ------------------------------------ 18.6/212.5 MB 8.2 MB/s eta 0:00:24
#    --- ------------------------------------ 20.2/212.5 MB 8.2 MB/s eta 0:00:24
#    --- ------------------------------------ 21.0/212.5 MB 7.9 MB/s eta 0:00:25
#    ---- ----------------------------------- 22.5/212.5 MB 7.8 MB/s eta 0:00:25
#    ---- ----------------------------------- 23.9/212.5 MB 7.7 MB/s eta 0:00:25
#    ---- ----------------------------------- 25.7/212.5 MB 7.7 MB/s eta 0:00:25
#    ----- ---------------------------------- 27.3/212.5 MB 7.7 MB/s eta 0:00:25
#    ----- ---------------------------------- 28.0/212.5 MB 7.6 MB/s eta 0:00:25
#    ----- ---------------------------------- 29.1/212.5 MB 7.3 MB/s eta 0:00:26
#    ----- ---------------------------------- 30.7/212.5 MB 7.4 MB/s eta 0:00:25
#    ------ --------------------------------- 32.2/212.5 MB 7.4 MB/s eta 0:00:25
#    ------ --------------------------------- 34.3/212.5 MB 7.5 MB/s eta 0:00:24
#    ------ --------------------------------- 35.4/212.5 MB 7.5 MB/s eta 0:00:24
#    ------ --------------------------------- 36.4/212.5 MB 7.3 MB/s eta 0:00:25
#    ------ --------------------------------- 37.0/212.5 MB 7.1 MB/s eta 0:00:25
#    ------- -------------------------------- 37.7/212.5 MB 7.0 MB/s eta 0:00:26
#    ------- -------------------------------- 39.3/212.5 MB 7.0 MB/s eta 0:00:25
#    ------- -------------------------------- 41.2/212.5 MB 7.1 MB/s eta 0:00:25
#    -------- ------------------------------- 43.0/212.5 MB 7.1 MB/s eta 0:00:24
#    -------- ------------------------------- 44.8/212.5 MB 7.2 MB/s eta 0:00:24
#    -------- ------------------------------- 46.7/212.5 MB 7.2 MB/s eta 0:00:24
#    --------- ------------------------------ 48.5/212.5 MB 7.3 MB/s eta 0:00:23
#    --------- ------------------------------ 50.3/212.5 MB 7.3 MB/s eta 0:00:23
#    --------- ------------------------------ 52.2/212.5 MB 7.3 MB/s eta 0:00:22
#    ---------- ----------------------------- 53.5/212.5 MB 7.3 MB/s eta 0:00:22
#    ---------- ----------------------------- 54.8/212.5 MB 7.3 MB/s eta 0:00:22
#    ---------- ----------------------------- 55.8/212.5 MB 7.3 MB/s eta 0:00:22
#    ---------- ----------------------------- 57.4/212.5 MB 7.2 MB/s eta 0:00:22
#    ----------- ---------------------------- 59.0/212.5 MB 7.3 MB/s eta 0:00:22
#    ----------- ---------------------------- 61.1/212.5 MB 7.3 MB/s eta 0:00:21
#    ----------- ---------------------------- 63.2/212.5 MB 7.4 MB/s eta 0:00:21
#    ------------ --------------------------- 65.3/212.5 MB 7.4 MB/s eta 0:00:20
#    ------------ --------------------------- 67.4/212.5 MB 7.5 MB/s eta 0:00:20
#    ------------- -------------------------- 69.5/212.5 MB 7.6 MB/s eta 0:00:19
#    ------------- -------------------------- 71.3/212.5 MB 7.6 MB/s eta 0:00:19
#    ------------- -------------------------- 73.1/212.5 MB 7.6 MB/s eta 0:00:19
#    -------------- ------------------------- 75.2/212.5 MB 7.7 MB/s eta 0:00:18
#    -------------- ------------------------- 77.1/212.5 MB 7.7 MB/s eta 0:00:18
#    -------------- ------------------------- 79.2/212.5 MB 7.7 MB/s eta 0:00:18
#    --------------- ------------------------ 81.3/212.5 MB 7.8 MB/s eta 0:00:17
#    --------------- ------------------------ 83.4/212.5 MB 7.8 MB/s eta 0:00:17
#    ---------------- ----------------------- 85.5/212.5 MB 7.9 MB/s eta 0:00:17
#    ---------------- ----------------------- 87.6/212.5 MB 7.9 MB/s eta 0:00:16
#    ---------------- ----------------------- 89.4/212.5 MB 7.9 MB/s eta 0:00:16
#    ----------------- ---------------------- 91.5/212.5 MB 8.0 MB/s eta 0:00:16
#    ----------------- ---------------------- 93.6/212.5 MB 8.0 MB/s eta 0:00:15
#    ------------------ --------------------- 95.7/212.5 MB 8.0 MB/s eta 0:00:15
#    ------------------ --------------------- 97.5/212.5 MB 8.0 MB/s eta 0:00:15
#    ------------------ --------------------- 99.6/212.5 MB 8.1 MB/s eta 0:00:14
#    ------------------- -------------------- 101.4/212.5 MB 8.1 MB/s eta 0:00:14
#    ------------------- -------------------- 103.0/212.5 MB 8.1 MB/s eta 0:00:14
#    ------------------- -------------------- 105.1/212.5 MB 8.1 MB/s eta 0:00:14
#    -------------------- ------------------- 106.7/212.5 MB 8.1 MB/s eta 0:00:14
#    -------------------- ------------------- 108.8/212.5 MB 8.1 MB/s eta 0:00:13
#    -------------------- ------------------- 110.9/212.5 MB 8.2 MB/s eta 0:00:13
#    --------------------- ------------------ 112.7/212.5 MB 8.2 MB/s eta 0:00:13
#    --------------------- ------------------ 114.8/212.5 MB 8.2 MB/s eta 0:00:12
#    --------------------- ------------------ 116.7/212.5 MB 8.2 MB/s eta 0:00:12
#    ---------------------- ----------------- 118.8/212.5 MB 8.2 MB/s eta 0:00:12
#    ---------------------- ----------------- 120.8/212.5 MB 8.3 MB/s eta 0:00:12
#    ----------------------- ---------------- 122.9/212.5 MB 8.3 MB/s eta 0:00:11
#    ----------------------- ---------------- 125.3/212.5 MB 8.3 MB/s eta 0:00:11
#    ----------------------- ---------------- 126.9/212.5 MB 8.3 MB/s eta 0:00:11
#    ------------------------ --------------- 128.7/212.5 MB 8.3 MB/s eta 0:00:11
#    ------------------------ --------------- 130.8/212.5 MB 8.3 MB/s eta 0:00:10
#    ------------------------- -------------- 132.9/212.5 MB 8.3 MB/s eta 0:00:10
#    ------------------------- -------------- 134.7/212.5 MB 8.4 MB/s eta 0:00:10
#    ------------------------- -------------- 136.6/212.5 MB 8.4 MB/s eta 0:00:10
#    -------------------------- ------------- 138.1/212.5 MB 8.3 MB/s eta 0:00:09
#    -------------------------- ------------- 139.7/212.5 MB 8.3 MB/s eta 0:00:09
#    -------------------------- ------------- 141.3/212.5 MB 8.3 MB/s eta 0:00:09
#    -------------------------- ------------- 142.6/212.5 MB 8.3 MB/s eta 0:00:09
#    --------------------------- ------------ 143.7/212.5 MB 8.3 MB/s eta 0:00:09
#    --------------------------- ------------ 145.8/212.5 MB 8.3 MB/s eta 0:00:09
#    --------------------------- ------------ 147.6/212.5 MB 8.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 149.7/212.5 MB 8.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 151.8/212.5 MB 8.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 153.9/212.5 MB 8.3 MB/s eta 0:00:08
#    ----------------------------- ---------- 156.0/212.5 MB 8.4 MB/s eta 0:00:07
#    ----------------------------- ---------- 157.8/212.5 MB 8.4 MB/s eta 0:00:07
#    ------------------------------ --------- 159.9/212.5 MB 8.4 MB/s eta 0:00:07
#    ------------------------------ --------- 161.7/212.5 MB 8.4 MB/s eta 0:00:07
#    ------------------------------ --------- 163.8/212.5 MB 8.4 MB/s eta 0:00:06
#    ------------------------------- -------- 165.9/212.5 MB 8.4 MB/s eta 0:00:06
#    ------------------------------- -------- 167.8/212.5 MB 8.4 MB/s eta 0:00:06
#    ------------------------------- -------- 169.9/212.5 MB 8.4 MB/s eta 0:00:06
#    -------------------------------- ------- 172.0/212.5 MB 8.5 MB/s eta 0:00:05
#    -------------------------------- ------- 174.1/212.5 MB 8.5 MB/s eta 0:00:05
#    --------------------------------- ------ 175.9/212.5 MB 8.5 MB/s eta 0:00:05
#    --------------------------------- ------ 178.0/212.5 MB 8.5 MB/s eta 0:00:05
#    --------------------------------- ------ 179.8/212.5 MB 8.5 MB/s eta 0:00:04
#    ---------------------------------- ----- 181.7/212.5 MB 8.5 MB/s eta 0:00:04
#    ---------------------------------- ----- 183.8/212.5 MB 8.5 MB/s eta 0:00:04
#    ---------------------------------- ----- 185.9/212.5 MB 8.5 MB/s eta 0:00:04
#    ----------------------------------- ---- 187.7/212.5 MB 8.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 189.8/212.5 MB 8.5 MB/s eta 0:00:03
#    ------------------------------------ --- 191.9/212.5 MB 8.5 MB/s eta 0:00:03
#    ------------------------------------ --- 194.0/212.5 MB 8.6 MB/s eta 0:00:03
#    ------------------------------------ --- 196.1/212.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------------- -- 197.9/212.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------------- -- 200.3/212.5 MB 8.6 MB/s eta 0:00:02
#    -------------------------------------- - 202.1/212.5 MB 8.6 MB/s eta 0:00:02
#    -------------------------------------- - 204.2/212.5 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 206.3/212.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  208.7/212.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  210.5/212.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 212.5/212.5 MB 8.5 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.3 MB 10.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.9/6.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.14.0 torch-2.7.0

# %%
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer
import tensorflow as tf

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = TFGPT2LMHeadModel.from_pretrained('gpt2')
# Out:
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
def generate_text(prompt, max_length=200):
    inputs = tokenizer.encode(prompt, return_tensors='tf')
    attention_mask = tf.ones_like(inputs)

    outputs = model.generate(
        inputs,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        no_repeat_ngram_size=2,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id  # Use end-of-sentence token as padding
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

print(generate_text("There was a girl named"))
# Out:
# There was a girl named Maria who asked for her autograph. I asked her to move out of a nearby house and then ran to her car and the girl sat in front of me. She said I wasn't in the right spot. And her voice was so cold, it cut me off.
#
# "It was like you were walking backwards," I said. "This was your room. The window on your bedroom side was closed. You don't want to fall into that. Do you want me to get out?"
#  (The story was not completely true.) She had asked me two questions; one was whether I wanted to be there, that I needed to make sure you never came in contact with me, and one, if you ever came close. Here is my reply:
# . . .
#  1. Are you in love with a man?
#  . —And I just got an email. They're looking for the perfect woman, which I don… 1 . Are they
